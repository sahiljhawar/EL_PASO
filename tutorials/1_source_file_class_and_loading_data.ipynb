# %% [markdown]
# # Tutorial: Loading data
#
# This notebook will teach you how to load data in the *EL-PASO* framework. You will load data from a csv file on disk, as well as download a cdf file from an online repository and load data from it.
#
# ## Loading from a csv file
#
# As a first step, we will load data from example_orbit.csv, which looks like this:

# %%
import pandas as pd

pd.read_csv("example_orbit.csv").head()
# Out:
#               DATETIME      alt(km)   lat(deg)    lon(deg)
# 0  2019-07-30 17:04:00  11362.75841  11.391923  154.268925
# 1  2019-07-30 17:09:00  11516.45781   8.645016  156.193306
# 2  2019-07-30 17:14:00  11650.92313   5.916772  158.021787
# 3  2019-07-30 17:19:00  11765.75939   3.209510  159.778169
# 4  2019-07-30 17:24:00  11860.64721   0.524741  161.484253

# %% [markdown]
# The data holds four columns describing the orbit of a satellite through time, altitude, latitude, and logitude. While we can certainly read in the data using pandas as above, we want to use the EL-PASO SourceFile class, which extracts the necessary data and puts it into variables. For this, we need to tell EL-PASO how to read the file by creating a list of ExtractionInfos. Each ExtractionInfo is used to create one variable based on data from the file and the given unit. The result_key parameter is used later on to identify the variable after loading.

# %%
from datetime import datetime, timezone

from astropy import units as u

import el_paso as ep

start_time = datetime(2019, 7, 30, 17, tzinfo=timezone.utc)
end_time   = datetime(2019, 8, 3, 5, tzinfo=timezone.utc)

extraction_infos = [
    ep.ExtractionInfo(
        result_key="Epoch",
        name_or_column="DATETIME",
        unit=u.dimensionless_unscaled,
    ),
    ep.ExtractionInfo(
        result_key="alt",
        name_or_column="alt(km)",
        unit=u.km,
    ),
    ep.ExtractionInfo(
        result_key="lon",
        name_or_column="lon(deg)",
        unit=u.km,
    ),
    ep.ExtractionInfo(
        result_key="lat",
        name_or_column="lat(deg)",
        unit=u.km,
    ),
]

# %% [markdown]
# Now we are ready to extract the data and put it into the variables. The extract_variables function return a dictionary holding Variables based on the extraction_infos.

# %%
variables = ep.extract_variables_from_files(start_time, end_time, "single_file",
                                             data_path=".", file_name_stem="example_orbit.csv",
                                             extraction_infos=extraction_infos)

print(variables.keys())
print(variables["Epoch"].metadata)
print(variables["Epoch"].get_data())
# Out:
# Extracting variables ...
# dict_keys(['Epoch', 'alt', 'lon', 'lat'])
# VariableMetadata(unit=Unit(dimensionless), original_cadence_seconds=0, source_files=['example_orbit.csv'], description='', processing_notes='', standard_name='')
# ['2019-07-30 17:04:00' '2019-07-30 17:09:00' '2019-07-30 17:14:00'
#  '2019-07-30 17:19:00' '2019-07-30 17:24:00' '2019-07-30 17:29:00'
#  '2019-07-30 17:34:00' '2019-07-30 17:39:00' '2019-07-30 17:44:00'
#  '2019-07-30 17:49:00' '2019-07-30 17:54:00' '2019-07-30 17:59:00'
#  '2019-07-30 18:04:00' '2019-07-30 18:09:00' '2019-07-30 18:14:00'
#  '2019-07-30 18:19:00' '2019-07-30 18:24:00' '2019-07-30 18:29:00'
#  '2019-07-30 18:34:00' '2019-07-30 18:39:00' '2019-07-30 18:44:00'
#  '2019-07-30 18:49:00' '2019-07-30 18:54:00' '2019-07-30 18:59:00'
#  '2019-07-30 19:04:00' '2019-07-30 19:09:00' '2019-07-30 19:14:00'
#  '2019-07-30 19:19:00' '2019-07-30 19:24:00' '2019-07-30 19:29:00'
#  '2019-07-30 19:34:00' '2019-07-30 19:39:00' '2019-07-30 19:44:00'
#  '2019-07-30 19:49:00' '2019-07-30 19:54:00' '2019-07-30 19:59:00'
#  '2019-07-30 20:04:00' '2019-07-30 20:09:00' '2019-07-30 20:14:00'
#  '2019-07-30 20:19:00' '2019-07-30 20:24:00' '2019-07-30 20:29:00'
#  '2019-07-30 20:34:00' '2019-07-30 20:39:00' '2019-07-30 20:44:00'
#  '2019-07-30 20:49:00' '2019-07-30 20:54:00' '2019-07-30 20:59:00'
#  '2019-07-30 21:04:00' '2019-07-30 21:09:00' '2019-07-30 21:14:00'
#  '2019-07-30 21:19:00' '2019-07-30 21:24:00' '2019-07-30 21:29:00'
#  '2019-07-30 21:34:00' '2019-07-30 21:39:00' '2019-07-30 21:44:00'
#  '2019-07-30 21:49:00' '2019-07-30 21:54:00' '2019-07-30 21:59:00'
#  '2019-07-30 22:04:00' '2019-07-30 22:09:00' '2019-07-30 22:14:00'
#  '2019-07-30 22:19:00' '2019-07-30 22:24:00' '2019-07-30 22:29:00'
#  '2019-07-30 22:34:00' '2019-07-30 22:39:00' '2019-07-30 22:44:00'
#  '2019-07-30 22:49:00' '2019-07-30 22:54:00' '2019-07-30 22:59:00'
#  '2019-07-30 23:04:00' '2019-07-30 23:09:00' '2019-07-30 23:14:00'
#  '2019-07-30 23:19:00' '2019-07-30 23:24:00' '2019-07-30 23:29:00'
#  '2019-07-30 23:34:00' '2019-07-30 23:39:00' '2019-07-30 23:44:00'
#  '2019-07-30 23:49:00' '2019-07-30 23:54:00' '2019-07-30 23:59:00'
#  '2019-07-31 00:04:00' '2019-07-31 00:09:00' '2019-07-31 00:14:00'
#  '2019-07-31 00:19:00' '2019-07-31 00:24:00' '2019-07-31 00:29:00'
#  '2019-07-31 00:34:00' '2019-07-31 00:39:00' '2019-07-31 00:44:00'
#  '2019-07-31 00:49:00' '2019-07-31 00:54:00' '2019-07-31 00:59:00'
#  '2019-07-31 01:04:00' '2019-07-31 01:09:00' '2019-07-31 01:14:00'
#  '2019-07-31 01:19:00' '2019-07-31 01:24:00' '2019-07-31 01:29:00'
#  '2019-07-31 01:34:00' '2019-07-31 01:39:00' '2019-07-31 01:44:00'
#  '2019-07-31 01:49:00' '2019-07-31 01:54:00' '2019-07-31 01:59:00'
#  '2019-07-31 02:04:00' '2019-07-31 02:09:00' '2019-07-31 02:14:00'
#  '2019-07-31 02:19:00' '2019-07-31 02:24:00' '2019-07-31 02:29:00'
#  '2019-07-31 02:34:00' '2019-07-31 02:39:00' '2019-07-31 02:44:00'
#  '2019-07-31 02:49:00' '2019-07-31 02:54:00' '2019-07-31 02:59:00'
#  '2019-07-31 03:04:00' '2019-07-31 03:09:00' '2019-07-31 03:14:00'
#  '2019-07-31 03:19:00' '2019-07-31 03:24:00' '2019-07-31 03:29:00'
#  '2019-07-31 03:34:00' '2019-07-31 03:39:00' '2019-07-31 03:44:00'
#  '2019-07-31 03:49:00' '2019-07-31 03:54:00' '2019-07-31 03:59:00'
#  '2019-07-31 04:04:00' '2019-07-31 04:09:00' '2019-07-31 04:14:00'
#  '2019-07-31 04:19:00' '2019-07-31 04:24:00' '2019-07-31 04:29:00'
#  '2019-07-31 04:34:00' '2019-07-31 04:39:00' '2019-07-31 04:44:00'
#  '2019-07-31 04:49:00' '2019-07-31 04:54:00' '2019-07-31 04:59:00'
#  '2019-07-31 05:04:00' '2019-07-31 05:09:00' '2019-07-31 05:14:00'
#  '2019-07-31 05:19:00' '2019-07-31 05:24:00' '2019-07-31 05:29:00'
#  '2019-07-31 05:34:00' '2019-07-31 05:39:00' '2019-07-31 05:44:00'
#  '2019-07-31 05:49:00' '2019-07-31 05:54:00' '2019-07-31 05:59:00'
#  '2019-07-31 06:04:00' '2019-07-31 06:09:00' '2019-07-31 06:14:00'
#  '2019-07-31 06:19:00' '2019-07-31 06:24:00' '2019-07-31 06:29:00'
#  '2019-07-31 06:34:00' '2019-07-31 06:39:00' '2019-07-31 06:44:00'
#  '2019-07-31 06:49:00' '2019-07-31 06:54:00' '2019-07-31 06:59:00'
#  '2019-07-31 07:04:00' '2019-07-31 07:09:00' '2019-07-31 07:14:00'
#  '2019-07-31 07:19:00' '2019-07-31 07:24:00' '2019-07-31 07:29:00'
#  '2019-07-31 07:34:00' '2019-07-31 07:39:00' '2019-07-31 07:44:00'
#  '2019-07-31 07:49:00' '2019-07-31 07:54:00' '2019-07-31 07:59:00'
#  '2019-07-31 08:04:00' '2019-07-31 08:09:00' '2019-07-31 08:14:00'
#  '2019-07-31 08:19:00' '2019-07-31 08:24:00' '2019-07-31 08:29:00'
#  '2019-07-31 08:34:00' '2019-07-31 08:39:00' '2019-07-31 08:44:00'
#  '2019-07-31 08:49:00' '2019-07-31 08:54:00' '2019-07-31 08:59:00'
#  '2019-07-31 09:04:00' '2019-07-31 09:09:00' '2019-07-31 09:14:00'
#  '2019-07-31 09:19:00' '2019-07-31 09:24:00' '2019-07-31 09:29:00'
#  '2019-07-31 09:34:00' '2019-07-31 09:39:00' '2019-07-31 09:44:00'
#  '2019-07-31 09:49:00' '2019-07-31 09:54:00' '2019-07-31 09:59:00'
#  '2019-07-31 10:04:00' '2019-07-31 10:09:00' '2019-07-31 10:14:00'
#  '2019-07-31 10:19:00' '2019-07-31 10:24:00' '2019-07-31 10:29:00'
#  '2019-07-31 10:34:00' '2019-07-31 10:39:00' '2019-07-31 10:44:00'
#  '2019-07-31 10:49:00' '2019-07-31 10:54:00' '2019-07-31 10:59:00'
#  '2019-07-31 11:04:00' '2019-07-31 11:09:00' '2019-07-31 11:14:00'
#  '2019-07-31 11:19:00' '2019-07-31 11:24:00' '2019-07-31 11:29:00'
#  '2019-07-31 11:34:00' '2019-07-31 11:39:00' '2019-07-31 11:44:00'
#  '2019-07-31 11:49:00' '2019-07-31 11:54:00' '2019-07-31 11:59:00'
#  '2019-07-31 12:04:00' '2019-07-31 12:09:00' '2019-07-31 12:14:00'
#  '2019-07-31 12:19:00' '2019-07-31 12:24:00' '2019-07-31 12:29:00'
#  '2019-07-31 12:34:00' '2019-07-31 12:39:00' '2019-07-31 12:44:00'
#  '2019-07-31 12:49:00' '2019-07-31 12:54:00' '2019-07-31 12:59:00'
#  '2019-07-31 13:04:00' '2019-07-31 13:09:00' '2019-07-31 13:14:00'
#  '2019-07-31 13:19:00' '2019-07-31 13:24:00' '2019-07-31 13:29:00'
#  '2019-07-31 13:34:00' '2019-07-31 13:39:00' '2019-07-31 13:44:00'
#  '2019-07-31 13:49:00' '2019-07-31 13:54:00' '2019-07-31 13:59:00'
#  '2019-07-31 14:04:00' '2019-07-31 14:09:00' '2019-07-31 14:14:00'
#  '2019-07-31 14:19:00' '2019-07-31 14:24:00' '2019-07-31 14:29:00'
#  '2019-07-31 14:34:00' '2019-07-31 14:39:00' '2019-07-31 14:44:00'
#  '2019-07-31 14:49:00' '2019-07-31 14:54:00' '2019-07-31 14:59:00'
#  '2019-07-31 15:04:00' '2019-07-31 15:09:00' '2019-07-31 15:14:00'
#  '2019-07-31 15:19:00' '2019-07-31 15:24:00' '2019-07-31 15:29:00'
#  '2019-07-31 15:34:00' '2019-07-31 15:39:00' '2019-07-31 15:44:00'
#  '2019-07-31 15:49:00' '2019-07-31 15:54:00' '2019-07-31 15:59:00'
#  '2019-07-31 16:04:00' '2019-07-31 16:09:00' '2019-07-31 16:14:00'
#  '2019-07-31 16:19:00' '2019-07-31 16:24:00' '2019-07-31 16:29:00'
#  '2019-07-31 16:34:00' '2019-07-31 16:39:00' '2019-07-31 16:44:00'
#  '2019-07-31 16:49:00' '2019-07-31 16:54:00' '2019-07-31 16:59:00'
#  '2019-07-31 17:04:00' '2019-07-31 17:09:00' '2019-07-31 17:14:00'
#  '2019-07-31 17:19:00' '2019-07-31 17:24:00' '2019-07-31 17:29:00'
#  '2019-07-31 17:34:00' '2019-07-31 17:39:00' '2019-07-31 17:44:00'
#  '2019-07-31 17:49:00' '2019-07-31 17:54:00' '2019-07-31 17:59:00'
#  '2019-07-31 18:04:00' '2019-07-31 18:09:00' '2019-07-31 18:14:00'
#  '2019-07-31 18:19:00' '2019-07-31 18:24:00' '2019-07-31 18:29:00'
#  '2019-07-31 18:34:00' '2019-07-31 18:39:00' '2019-07-31 18:44:00'
#  '2019-07-31 18:49:00' '2019-07-31 18:54:00' '2019-07-31 18:59:00'
#  '2019-07-31 19:04:00' '2019-07-31 19:09:00' '2019-07-31 19:14:00'
#  '2019-07-31 19:19:00' '2019-07-31 19:24:00' '2019-07-31 19:29:00'
#  '2019-07-31 19:34:00' '2019-07-31 19:39:00' '2019-07-31 19:44:00'
#  '2019-07-31 19:49:00' '2019-07-31 19:54:00' '2019-07-31 19:59:00'
#  '2019-07-31 20:04:00' '2019-07-31 20:09:00' '2019-07-31 20:14:00'
#  '2019-07-31 20:19:00' '2019-07-31 20:24:00' '2019-07-31 20:29:00'
#  '2019-07-31 20:34:00' '2019-07-31 20:39:00' '2019-07-31 20:44:00'
#  '2019-07-31 20:49:00' '2019-07-31 20:54:00' '2019-07-31 20:59:00'
#  '2019-07-31 21:04:00' '2019-07-31 21:09:00' '2019-07-31 21:14:00'
#  '2019-07-31 21:19:00' '2019-07-31 21:24:00' '2019-07-31 21:29:00'
#  '2019-07-31 21:34:00' '2019-07-31 21:39:00' '2019-07-31 21:44:00'
#  '2019-07-31 21:49:00' '2019-07-31 21:54:00' '2019-07-31 21:59:00'
#  '2019-07-31 22:04:00' '2019-07-31 22:09:00' '2019-07-31 22:14:00'
#  '2019-07-31 22:19:00' '2019-07-31 22:24:00' '2019-07-31 22:29:00'
#  '2019-07-31 22:34:00' '2019-07-31 22:39:00' '2019-07-31 22:44:00'
#  '2019-07-31 22:49:00' '2019-07-31 22:54:00' '2019-07-31 22:59:00'
#  '2019-07-31 23:04:00' '2019-07-31 23:09:00' '2019-07-31 23:14:00'
#  '2019-07-31 23:19:00' '2019-07-31 23:24:00' '2019-07-31 23:29:00'
#  '2019-07-31 23:34:00' '2019-07-31 23:39:00' '2019-07-31 23:44:00'
#  '2019-07-31 23:49:00' '2019-07-31 23:54:00' '2019-07-31 23:59:00'
#  '2019-08-01 00:04:00' '2019-08-01 00:09:00' '2019-08-01 00:14:00'
#  '2019-08-01 00:19:00' '2019-08-01 00:24:00' '2019-08-01 00:29:00'
#  '2019-08-01 00:34:00' '2019-08-01 00:39:00' '2019-08-01 00:44:00'
#  '2019-08-01 00:49:00' '2019-08-01 00:54:00' '2019-08-01 00:59:00'
#  '2019-08-01 01:04:00' '2019-08-01 01:09:00' '2019-08-01 01:14:00'
#  '2019-08-01 01:19:00' '2019-08-01 01:24:00' '2019-08-01 01:29:00'
#  '2019-08-01 01:34:00' '2019-08-01 01:39:00' '2019-08-01 01:44:00'
#  '2019-08-01 01:49:00' '2019-08-01 01:54:00' '2019-08-01 01:59:00'
#  '2019-08-01 02:04:00' '2019-08-01 02:09:00' '2019-08-01 02:14:00'
#  '2019-08-01 02:19:00' '2019-08-01 02:24:00' '2019-08-01 02:29:00'
#  '2019-08-01 02:34:00' '2019-08-01 02:39:00' '2019-08-01 02:44:00'
#  '2019-08-01 02:49:00' '2019-08-01 02:54:00' '2019-08-01 02:59:00'
#  '2019-08-01 03:04:00' '2019-08-01 03:09:00' '2019-08-01 03:14:00'
#  '2019-08-01 03:19:00' '2019-08-01 03:24:00' '2019-08-01 03:29:00'
#  '2019-08-01 03:34:00' '2019-08-01 03:39:00' '2019-08-01 03:44:00'
#  '2019-08-01 03:49:00' '2019-08-01 03:54:00' '2019-08-01 03:59:00'
#  '2019-08-01 04:04:00' '2019-08-01 04:09:00' '2019-08-01 04:14:00'
#  '2019-08-01 04:19:00' '2019-08-01 04:24:00' '2019-08-01 04:29:00'
#  '2019-08-01 04:34:00' '2019-08-01 04:39:00' '2019-08-01 04:44:00'
#  '2019-08-01 04:49:00' '2019-08-01 04:54:00' '2019-08-01 04:59:00'
#  '2019-08-01 05:04:00' '2019-08-01 05:09:00' '2019-08-01 05:14:00'
#  '2019-08-01 05:19:00' '2019-08-01 05:24:00' '2019-08-01 05:29:00'
#  '2019-08-01 05:34:00' '2019-08-01 05:39:00' '2019-08-01 05:44:00'
#  '2019-08-01 05:49:00' '2019-08-01 05:54:00' '2019-08-01 05:59:00'
#  '2019-08-01 06:04:00' '2019-08-01 06:09:00' '2019-08-01 06:14:00'
#  '2019-08-01 06:19:00' '2019-08-01 06:24:00' '2019-08-01 06:29:00'
#  '2019-08-01 06:34:00' '2019-08-01 06:39:00' '2019-08-01 06:44:00'
#  '2019-08-01 06:49:00' '2019-08-01 06:54:00' '2019-08-01 06:59:00'
#  '2019-08-01 07:04:00' '2019-08-01 07:09:00' '2019-08-01 07:14:00'
#  '2019-08-01 07:19:00' '2019-08-01 07:24:00' '2019-08-01 07:29:00'
#  '2019-08-01 07:34:00' '2019-08-01 07:39:00' '2019-08-01 07:44:00'
#  '2019-08-01 07:49:00' '2019-08-01 07:54:00' '2019-08-01 07:59:00'
#  '2019-08-01 08:04:00' '2019-08-01 08:09:00' '2019-08-01 08:14:00'
#  '2019-08-01 08:19:00' '2019-08-01 08:24:00' '2019-08-01 08:29:00'
#  '2019-08-01 08:34:00' '2019-08-01 08:39:00' '2019-08-01 08:44:00'
#  '2019-08-01 08:49:00' '2019-08-01 08:54:00' '2019-08-01 08:59:00'
#  '2019-08-01 09:04:00' '2019-08-01 09:09:00' '2019-08-01 09:14:00'
#  '2019-08-01 09:19:00' '2019-08-01 09:24:00' '2019-08-01 09:29:00'
#  '2019-08-01 09:34:00' '2019-08-01 09:39:00' '2019-08-01 09:44:00'
#  '2019-08-01 09:49:00' '2019-08-01 09:54:00' '2019-08-01 09:59:00'
#  '2019-08-01 10:04:00' '2019-08-01 10:09:00' '2019-08-01 10:14:00'
#  '2019-08-01 10:19:00' '2019-08-01 10:24:00' '2019-08-01 10:29:00'
#  '2019-08-01 10:34:00' '2019-08-01 10:39:00' '2019-08-01 10:44:00'
#  '2019-08-01 10:49:00' '2019-08-01 10:54:00' '2019-08-01 10:59:00'
#  '2019-08-01 11:04:00' '2019-08-01 11:09:00' '2019-08-01 11:14:00'
#  '2019-08-01 11:19:00' '2019-08-01 11:24:00' '2019-08-01 11:29:00'
#  '2019-08-01 11:34:00' '2019-08-01 11:39:00' '2019-08-01 11:44:00'
#  '2019-08-01 11:49:00' '2019-08-01 11:54:00' '2019-08-01 11:59:00'
#  '2019-08-01 12:04:00' '2019-08-01 12:09:00' '2019-08-01 12:14:00'
#  '2019-08-01 12:19:00' '2019-08-01 12:24:00' '2019-08-01 12:29:00'
#  '2019-08-01 12:34:00' '2019-08-01 12:39:00' '2019-08-01 12:44:00'
#  '2019-08-01 12:49:00' '2019-08-01 12:54:00' '2019-08-01 12:59:00'
#  '2019-08-01 13:04:00' '2019-08-01 13:09:00' '2019-08-01 13:14:00'
#  '2019-08-01 13:19:00' '2019-08-01 13:24:00' '2019-08-01 13:29:00'
#  '2019-08-01 13:34:00' '2019-08-01 13:39:00' '2019-08-01 13:44:00'
#  '2019-08-01 13:49:00' '2019-08-01 13:54:00' '2019-08-01 13:59:00'
#  '2019-08-01 14:04:00' '2019-08-01 14:09:00' '2019-08-01 14:14:00'
#  '2019-08-01 14:19:00' '2019-08-01 14:24:00' '2019-08-01 14:29:00'
#  '2019-08-01 14:34:00' '2019-08-01 14:39:00' '2019-08-01 14:44:00'
#  '2019-08-01 14:49:00' '2019-08-01 14:54:00' '2019-08-01 14:59:00'
#  '2019-08-01 15:04:00' '2019-08-01 15:09:00' '2019-08-01 15:14:00'
#  '2019-08-01 15:19:00' '2019-08-01 15:24:00' '2019-08-01 15:29:00'
#  '2019-08-01 15:34:00' '2019-08-01 15:39:00' '2019-08-01 15:44:00'
#  '2019-08-01 15:49:00' '2019-08-01 15:54:00' '2019-08-01 15:59:00'
#  '2019-08-01 16:04:00' '2019-08-01 16:09:00' '2019-08-01 16:14:00'
#  '2019-08-01 16:19:00' '2019-08-01 16:24:00' '2019-08-01 16:29:00'
#  '2019-08-01 16:34:00' '2019-08-01 16:39:00' '2019-08-01 16:44:00'
#  '2019-08-01 16:49:00' '2019-08-01 16:54:00' '2019-08-01 16:59:00'
#  '2019-08-01 17:04:00' '2019-08-01 17:09:00' '2019-08-01 17:14:00'
#  '2019-08-01 17:19:00' '2019-08-01 17:24:00' '2019-08-01 17:29:00'
#  '2019-08-01 17:34:00' '2019-08-01 17:39:00' '2019-08-01 17:44:00'
#  '2019-08-01 17:49:00' '2019-08-01 17:54:00' '2019-08-01 17:59:00'
#  '2019-08-01 18:04:00' '2019-08-01 18:09:00' '2019-08-01 18:14:00'
#  '2019-08-01 18:19:00' '2019-08-01 18:24:00' '2019-08-01 18:29:00'
#  '2019-08-01 18:34:00' '2019-08-01 18:39:00' '2019-08-01 18:44:00'
#  '2019-08-01 18:49:00' '2019-08-01 18:54:00' '2019-08-01 18:59:00'
#  '2019-08-01 19:04:00' '2019-08-01 19:09:00' '2019-08-01 19:14:00'
#  '2019-08-01 19:19:00' '2019-08-01 19:24:00' '2019-08-01 19:29:00'
#  '2019-08-01 19:34:00' '2019-08-01 19:39:00' '2019-08-01 19:44:00'
#  '2019-08-01 19:49:00' '2019-08-01 19:54:00' '2019-08-01 19:59:00'
#  '2019-08-01 20:04:00' '2019-08-01 20:09:00' '2019-08-01 20:14:00'
#  '2019-08-01 20:19:00' '2019-08-01 20:24:00' '2019-08-01 20:29:00'
#  '2019-08-01 20:34:00' '2019-08-01 20:39:00' '2019-08-01 20:44:00'
#  '2019-08-01 20:49:00' '2019-08-01 20:54:00' '2019-08-01 20:59:00'
#  '2019-08-01 21:04:00' '2019-08-01 21:09:00' '2019-08-01 21:14:00'
#  '2019-08-01 21:19:00' '2019-08-01 21:24:00' '2019-08-01 21:29:00'
#  '2019-08-01 21:34:00' '2019-08-01 21:39:00' '2019-08-01 21:44:00'
#  '2019-08-01 21:49:00' '2019-08-01 21:54:00' '2019-08-01 21:59:00'
#  '2019-08-01 22:04:00' '2019-08-01 22:09:00' '2019-08-01 22:14:00'
#  '2019-08-01 22:19:00' '2019-08-01 22:24:00' '2019-08-01 22:29:00'
#  '2019-08-01 22:34:00' '2019-08-01 22:39:00' '2019-08-01 22:44:00'
#  '2019-08-01 22:49:00' '2019-08-01 22:54:00' '2019-08-01 22:59:00'
#  '2019-08-01 23:04:00' '2019-08-01 23:09:00' '2019-08-01 23:14:00'
#  '2019-08-01 23:19:00' '2019-08-01 23:24:00' '2019-08-01 23:29:00'
#  '2019-08-01 23:34:00' '2019-08-01 23:39:00' '2019-08-01 23:44:00'
#  '2019-08-01 23:49:00' '2019-08-01 23:54:00' '2019-08-01 23:59:00'
#  '2019-08-02 00:04:00' '2019-08-02 00:09:00' '2019-08-02 00:14:00'
#  '2019-08-02 00:19:00' '2019-08-02 00:24:00' '2019-08-02 00:29:00'
#  '2019-08-02 00:34:00' '2019-08-02 00:39:00' '2019-08-02 00:44:00'
#  '2019-08-02 00:49:00' '2019-08-02 00:54:00' '2019-08-02 00:59:00'
#  '2019-08-02 01:04:00' '2019-08-02 01:09:00' '2019-08-02 01:14:00'
#  '2019-08-02 01:19:00' '2019-08-02 01:24:00' '2019-08-02 01:29:00'
#  '2019-08-02 01:34:00' '2019-08-02 01:39:00' '2019-08-02 01:44:00'
#  '2019-08-02 01:49:00' '2019-08-02 01:54:00' '2019-08-02 01:59:00'
#  '2019-08-02 02:04:00' '2019-08-02 02:09:00' '2019-08-02 02:14:00'
#  '2019-08-02 02:19:00' '2019-08-02 02:24:00' '2019-08-02 02:29:00'
#  '2019-08-02 02:34:00' '2019-08-02 02:39:00' '2019-08-02 02:44:00'
#  '2019-08-02 02:49:00' '2019-08-02 02:54:00' '2019-08-02 02:59:00'
#  '2019-08-02 03:04:00' '2019-08-02 03:09:00' '2019-08-02 03:14:00'
#  '2019-08-02 03:19:00' '2019-08-02 03:24:00' '2019-08-02 03:29:00'
#  '2019-08-02 03:34:00' '2019-08-02 03:39:00' '2019-08-02 03:44:00'
#  '2019-08-02 03:49:00' '2019-08-02 03:54:00' '2019-08-02 03:59:00'
#  '2019-08-02 04:04:00' '2019-08-02 04:09:00' '2019-08-02 04:14:00'
#  '2019-08-02 04:19:00' '2019-08-02 04:24:00' '2019-08-02 04:29:00'
#  '2019-08-02 04:34:00' '2019-08-02 04:39:00' '2019-08-02 04:44:00'
#  '2019-08-02 04:49:00' '2019-08-02 04:54:00' '2019-08-02 04:59:00'
#  '2019-08-02 05:04:00' '2019-08-02 05:09:00' '2019-08-02 05:14:00'
#  '2019-08-02 05:19:00' '2019-08-02 05:24:00' '2019-08-02 05:29:00'
#  '2019-08-02 05:34:00' '2019-08-02 05:39:00' '2019-08-02 05:44:00'
#  '2019-08-02 05:49:00' '2019-08-02 05:54:00' '2019-08-02 05:59:00'
#  '2019-08-02 06:04:00' '2019-08-02 06:09:00' '2019-08-02 06:14:00'
#  '2019-08-02 06:19:00' '2019-08-02 06:24:00' '2019-08-02 06:29:00'
#  '2019-08-02 06:34:00' '2019-08-02 06:39:00' '2019-08-02 06:44:00'
#  '2019-08-02 06:49:00' '2019-08-02 06:54:00' '2019-08-02 06:59:00'
#  '2019-08-02 07:04:00' '2019-08-02 07:09:00' '2019-08-02 07:14:00'
#  '2019-08-02 07:19:00' '2019-08-02 07:24:00' '2019-08-02 07:29:00'
#  '2019-08-02 07:34:00' '2019-08-02 07:39:00' '2019-08-02 07:44:00'
#  '2019-08-02 07:49:00' '2019-08-02 07:54:00' '2019-08-02 07:59:00'
#  '2019-08-02 08:04:00' '2019-08-02 08:09:00' '2019-08-02 08:14:00'
#  '2019-08-02 08:19:00' '2019-08-02 08:24:00' '2019-08-02 08:29:00'
#  '2019-08-02 08:34:00' '2019-08-02 08:39:00' '2019-08-02 08:44:00'
#  '2019-08-02 08:49:00' '2019-08-02 08:54:00' '2019-08-02 08:59:00'
#  '2019-08-02 09:04:00' '2019-08-02 09:09:00' '2019-08-02 09:14:00'
#  '2019-08-02 09:19:00' '2019-08-02 09:24:00' '2019-08-02 09:29:00'
#  '2019-08-02 09:34:00' '2019-08-02 09:39:00' '2019-08-02 09:44:00'
#  '2019-08-02 09:49:00' '2019-08-02 09:54:00' '2019-08-02 09:59:00'
#  '2019-08-02 10:04:00' '2019-08-02 10:09:00' '2019-08-02 10:14:00'
#  '2019-08-02 10:19:00' '2019-08-02 10:24:00' '2019-08-02 10:29:00'
#  '2019-08-02 10:34:00' '2019-08-02 10:39:00' '2019-08-02 10:44:00'
#  '2019-08-02 10:49:00' '2019-08-02 10:54:00' '2019-08-02 10:59:00'
#  '2019-08-02 11:04:00' '2019-08-02 11:09:00' '2019-08-02 11:14:00'
#  '2019-08-02 11:19:00' '2019-08-02 11:24:00' '2019-08-02 11:29:00'
#  '2019-08-02 11:34:00' '2019-08-02 11:39:00' '2019-08-02 11:44:00'
#  '2019-08-02 11:49:00' '2019-08-02 11:54:00' '2019-08-02 11:59:00'
#  '2019-08-02 12:04:00' '2019-08-02 12:09:00' '2019-08-02 12:14:00'
#  '2019-08-02 12:19:00' '2019-08-02 12:24:00' '2019-08-02 12:29:00'
#  '2019-08-02 12:34:00' '2019-08-02 12:39:00' '2019-08-02 12:44:00'
#  '2019-08-02 12:49:00' '2019-08-02 12:54:00' '2019-08-02 12:59:00'
#  '2019-08-02 13:04:00' '2019-08-02 13:09:00' '2019-08-02 13:14:00'
#  '2019-08-02 13:19:00' '2019-08-02 13:24:00' '2019-08-02 13:29:00'
#  '2019-08-02 13:34:00' '2019-08-02 13:39:00' '2019-08-02 13:44:00'
#  '2019-08-02 13:49:00' '2019-08-02 13:54:00' '2019-08-02 13:59:00'
#  '2019-08-02 14:04:00' '2019-08-02 14:09:00' '2019-08-02 14:14:00'
#  '2019-08-02 14:19:00' '2019-08-02 14:24:00' '2019-08-02 14:29:00'
#  '2019-08-02 14:34:00' '2019-08-02 14:39:00' '2019-08-02 14:44:00'
#  '2019-08-02 14:49:00' '2019-08-02 14:54:00' '2019-08-02 14:59:00'
#  '2019-08-02 15:04:00' '2019-08-02 15:09:00' '2019-08-02 15:14:00'
#  '2019-08-02 15:19:00' '2019-08-02 15:24:00' '2019-08-02 15:29:00'
#  '2019-08-02 15:34:00' '2019-08-02 15:39:00' '2019-08-02 15:44:00'
#  '2019-08-02 15:49:00' '2019-08-02 15:54:00' '2019-08-02 15:59:00'
#  '2019-08-02 16:04:00' '2019-08-02 16:09:00' '2019-08-02 16:14:00'
#  '2019-08-02 16:19:00' '2019-08-02 16:24:00' '2019-08-02 16:29:00'
#  '2019-08-02 16:34:00' '2019-08-02 16:39:00' '2019-08-02 16:44:00'
#  '2019-08-02 16:49:00' '2019-08-02 16:54:00' '2019-08-02 16:59:00'
#  '2019-08-02 17:04:00' '2019-08-02 17:09:00' '2019-08-02 17:14:00'
#  '2019-08-02 17:19:00' '2019-08-02 17:24:00' '2019-08-02 17:29:00'
#  '2019-08-02 17:34:00' '2019-08-02 17:39:00' '2019-08-02 17:44:00'
#  '2019-08-02 17:49:00' '2019-08-02 17:54:00' '2019-08-02 17:59:00'
#  '2019-08-02 18:04:00' '2019-08-02 18:09:00' '2019-08-02 18:14:00'
#  '2019-08-02 18:19:00' '2019-08-02 18:24:00' '2019-08-02 18:29:00'
#  '2019-08-02 18:34:00' '2019-08-02 18:39:00' '2019-08-02 18:44:00'
#  '2019-08-02 18:49:00' '2019-08-02 18:54:00' '2019-08-02 18:59:00'
#  '2019-08-02 19:04:00' '2019-08-02 19:09:00' '2019-08-02 19:14:00'
#  '2019-08-02 19:19:00' '2019-08-02 19:24:00' '2019-08-02 19:29:00'
#  '2019-08-02 19:34:00' '2019-08-02 19:39:00' '2019-08-02 19:44:00'
#  '2019-08-02 19:49:00' '2019-08-02 19:54:00' '2019-08-02 19:59:00'
#  '2019-08-02 20:04:00' '2019-08-02 20:09:00' '2019-08-02 20:14:00'
#  '2019-08-02 20:19:00' '2019-08-02 20:24:00' '2019-08-02 20:29:00'
#  '2019-08-02 20:34:00' '2019-08-02 20:39:00' '2019-08-02 20:44:00'
#  '2019-08-02 20:49:00' '2019-08-02 20:54:00' '2019-08-02 20:59:00'
#  '2019-08-02 21:04:00' '2019-08-02 21:09:00' '2019-08-02 21:14:00'
#  '2019-08-02 21:19:00' '2019-08-02 21:24:00' '2019-08-02 21:29:00'
#  '2019-08-02 21:34:00' '2019-08-02 21:39:00' '2019-08-02 21:44:00'
#  '2019-08-02 21:49:00' '2019-08-02 21:54:00' '2019-08-02 21:59:00'
#  '2019-08-02 22:04:00' '2019-08-02 22:09:00' '2019-08-02 22:14:00'
#  '2019-08-02 22:19:00' '2019-08-02 22:24:00' '2019-08-02 22:29:00'
#  '2019-08-02 22:34:00' '2019-08-02 22:39:00' '2019-08-02 22:44:00'
#  '2019-08-02 22:49:00' '2019-08-02 22:54:00' '2019-08-02 22:59:00'
#  '2019-08-02 23:04:00' '2019-08-02 23:09:00' '2019-08-02 23:14:00'
#  '2019-08-02 23:19:00' '2019-08-02 23:24:00' '2019-08-02 23:29:00'
#  '2019-08-02 23:34:00' '2019-08-02 23:39:00' '2019-08-02 23:44:00'
#  '2019-08-02 23:49:00' '2019-08-02 23:54:00' '2019-08-02 23:59:00'
#  '2019-08-03 00:04:00' '2019-08-03 00:09:00' '2019-08-03 00:14:00'
#  '2019-08-03 00:19:00' '2019-08-03 00:24:00' '2019-08-03 00:29:00'
#  '2019-08-03 00:34:00' '2019-08-03 00:39:00' '2019-08-03 00:44:00'
#  '2019-08-03 00:49:00' '2019-08-03 00:54:00' '2019-08-03 00:59:00'
#  '2019-08-03 01:04:00' '2019-08-03 01:09:00' '2019-08-03 01:14:00'
#  '2019-08-03 01:19:00' '2019-08-03 01:24:00' '2019-08-03 01:29:00'
#  '2019-08-03 01:34:00' '2019-08-03 01:39:00' '2019-08-03 01:44:00'
#  '2019-08-03 01:49:00' '2019-08-03 01:54:00' '2019-08-03 01:59:00'
#  '2019-08-03 02:04:00' '2019-08-03 02:09:00' '2019-08-03 02:14:00'
#  '2019-08-03 02:19:00' '2019-08-03 02:24:00' '2019-08-03 02:29:00'
#  '2019-08-03 02:34:00' '2019-08-03 02:39:00' '2019-08-03 02:44:00'
#  '2019-08-03 02:49:00' '2019-08-03 02:54:00' '2019-08-03 02:59:00'
#  '2019-08-03 03:04:00' '2019-08-03 03:09:00' '2019-08-03 03:14:00'
#  '2019-08-03 03:19:00' '2019-08-03 03:24:00' '2019-08-03 03:29:00'
#  '2019-08-03 03:34:00' '2019-08-03 03:39:00' '2019-08-03 03:44:00'
#  '2019-08-03 03:49:00' '2019-08-03 03:54:00' '2019-08-03 03:59:00'
#  '2019-08-03 04:04:00' '2019-08-03 04:09:00' '2019-08-03 04:14:00'
#  '2019-08-03 04:19:00']

# %% [markdown]
# ## Download and load a cdf file
#
# This example will show you how to inspect a CDF file and how to extract variables from it using a *SourceFile*.
#
# First thing you want to do is knowing what are the contents of the CDF file. For this, a script is provided by EL-PASO, which prints a table with all relevant information:

# %%
import sys
sys.path.append("../")

from scripts.inspect_cdf_file import inspect_cdf_file

inspect_cdf_file("rbspa_rel04_ect-hope-pa-l3_20170708_v7.4.0.cdf")
# Out:
# Variable name     Data Type    Units                               Data Shape      Fill value              Description
# ----------------  -----------  ----------------------------------  --------------  ----------------------  -----------------------------------------------------------------------
# B_Calc_Ele        CDF_FLOAT    nT                                  (4165,)         -9.999999848243207e+30  Model magnetic field strength (electron timebase)
# B_Calc_Ion        CDF_FLOAT    nT                                  (3446,)         -9.999999848243207e+30  Model magnetic field strength (ion timebase)
# B_Eq_Ele          CDF_FLOAT    nT                                  (4165,)         -9.999999848243207e+30  Model magnetic field strength at magnetic equator (electron timebase)
# B_Eq_Ion          CDF_FLOAT    nT                                  (3446,)         -9.999999848243207e+30  Model magnetic field strength at magnetic equator (ion timebase)
# ENERGY_Ele_DELTA  CDF_FLOAT    eV                                  (4165, 72)      -9.999999848243207e+30  ENERGY_Ele_DELTA
# ENERGY_Ion_DELTA  CDF_FLOAT    eV                                  (3446, 72)      -9.999999848243207e+30  ENERGY_Ion_DELTA
# Energy_LABL       CDF_CHAR                                         (72, 1)                                 Energy_LABL
# Epoch_Ele         CDF_EPOCH                                        (4165,)         -1e+31                  Timebase for electron measurments
# Epoch_Ele_DELTA   CDF_REAL4    ms                                  (4165,)         -9.999999848243207e+30  Half sample time
# Epoch_Ion         CDF_EPOCH                                        (3446,)         -1e+31                  Timebase for ion measurments
# Epoch_Ion_DELTA   CDF_REAL4    ms                                  (3446,)         -9.999999848243207e+30  Half sample time
# FLAGS             CDF_CHAR                                         (8, 1)                                  Flag type descriptions
# Flags_Ele         CDF_UINT1                                        (4165, 8)       255                     Flags on electron data
# Flags_Ion         CDF_UINT1                                        (3446, 8)       255                     Flags on ion data
# HOPE_ENERGY_Ele   CDF_FLOAT    eV                                  (4165, 72)      -9.999999848243207e+30  HOPE_ENERGY_Ele
# HOPE_ENERGY_Ion   CDF_FLOAT    eV                                  (3446, 72)      -9.999999848243207e+30  HOPE_ENERGY_Ion
# I_Ele             CDF_FLOAT                                        (4165,)         -9.999999848243207e+30  Adiabatic invariant (bounce) (electron timebase)
# I_Ion             CDF_FLOAT                                        (3446,)         -9.999999848243207e+30  Adiabatic invariant (bounce) (ion timebase)
# L_Ele             CDF_FLOAT                                        (4165,)         -9.999999848243207e+30  Calculated McIlwains L parameter (electron timebase)
# L_Ion             CDF_FLOAT                                        (3446,)         -9.999999848243207e+30  Calculated McIlwains L parameter (ion timebase)
# L_star_Ele        CDF_FLOAT                                        (4165,)         -9.999999848243207e+30  Calculated Roederers L* parameter (electron timebase)
# L_star_Ion        CDF_FLOAT                                        (3446,)         -9.999999848243207e+30  Calculated Roederers L* parameter (ion timebase)
# MLT_Ele           CDF_FLOAT    h                                   (4165,)         -9.999999848243207e+30  Calculated Magnetic Local Time (electron timebase)
# MLT_Ion           CDF_FLOAT    h                                   (3446,)         -9.999999848243207e+30  Calculated Magnetic Local Time (ion timebase)
# Position_Ele      CDF_FLOAT    km                                  (4165, 3)       -9.999999848243207e+30  Position of the satellite in geographic coordinates (electron timebase)
# Position_Ion      CDF_FLOAT    km                                  (3446, 3)       -9.999999848243207e+30  Position of the satellite in geographic coordinates (ion timebase)
# Position_LABL_1   CDF_CHAR                                         (3, 1)                                  Position_LABL_1
# PITCH_ANGLE       CDF_FLOAT                                        (11,)           -9.999999848243207e+30  Pitch angle of the particle [0, 180]
# Pitch_LABL        CDF_CHAR                                         (11, 1)                                 Pitch_LABL
# Mode_Ion          CDF_UINT1                                        (3446,)         255                     Mode of ion data
# Mode_Ele          CDF_UINT1                                        (4165,)         255                     Mode of electron data
# Counts_E_Omni     CDF_FLOAT                                        (4165, 72)      -9.999999848243207e+30  HOPE electron counts
# Counts_E          CDF_FLOAT                                        (4165, 11, 72)  -9.999999848243207e+30  HOPE electron counts
# Counts_He_Omni    CDF_FLOAT                                        (3446, 72)      -9.999999848243207e+30  HOPE helium counts
# Counts_He         CDF_FLOAT                                        (3446, 11, 72)  -9.999999848243207e+30  HOPE helium counts
# Counts_O_Omni     CDF_FLOAT                                        (3446, 72)      -9.999999848243207e+30  HOPE Oxygen counts
# Counts_O          CDF_FLOAT                                        (3446, 11, 72)  -9.999999848243207e+30  HOPE Oxygen counts
# Counts_P_Omni     CDF_FLOAT                                        (3446, 72)      -9.999999848243207e+30  HOPE proton counts
# Counts_P          CDF_FLOAT                                        (3446, 11, 72)  -9.999999848243207e+30  HOPE proton counts
# Ele_SAMPLES_Omni  CDF_UINT1                                        (4165, 72)      255                     HOPE differential electron flux
# Ele_SAMPLES       CDF_UINT1                                        (4165, 11, 72)  255                     HOPE differential electron flux
# Ion_SAMPLES_Omni  CDF_UINT1                                        (3446, 72)      255                     Number of ion measurements per bin
# Ion_SAMPLES       CDF_UINT1                                        (3446, 11, 72)  255                     Number of ion measurements per bin
# FEDO              CDF_FLOAT    s!E-1!Ncm!E-2!Nster!E-1!NkeV!E-1!N  (4165, 72)      -9.999999848243207e+30  HOPE omnidirectional differential electron flux
# FEDU              CDF_FLOAT    s!E-1!Ncm!E-2!Nster!E-1!NkeV!E-1!N  (4165, 11, 72)  -9.999999848243207e+30  HOPE differential electron flux
# FPDO              CDF_FLOAT    s!E-1!Ncm!E-2!Nster!E-1!NkeV!E-1!N  (3446, 72)      -9.999999848243207e+30  HOPE omnidirectional differential proton flux
# FPDU              CDF_FLOAT    s!E-1!Ncm!E-2!Nster!E-1!NkeV!E-1!N  (3446, 11, 72)  -9.999999848243207e+30  HOPE differential proton flux
# FODO              CDF_FLOAT    s!E-1!Ncm!E-2!Nster!E-1!NkeV!E-1!N  (3446, 72)      -9.999999848243207e+30  HOPE omnidirectional differential oxygen flux
# FODU              CDF_FLOAT    s!E-1!Ncm!E-2!Nster!E-1!NkeV!E-1!N  (3446, 11, 72)  -9.999999848243207e+30  HOPE differential oxygen flux
# FHEDO             CDF_FLOAT    s!E-1!Ncm!E-2!Nster!E-1!NkeV!E-1!N  (3446, 72)      -9.999999848243207e+30  HOPE omnidirectional differential helium flux
# FHEDU             CDF_FLOAT    s!E-1!Ncm!E-2!Nster!E-1!NkeV!E-1!N  (3446, 11, 72)  -9.999999848243207e+30  HOPE differential helium flux

# %% [markdown]
# The next step is to think which variables you want to use for the processing and translating them to EL-PASO ExtractionInfos.

# %%
from astropy import units as u

import el_paso as ep

extraction_infos = [
    ep.ExtractionInfo(
        result_key="Epoch",
        name_or_column="Epoch_Ele",
        unit=u.tt2000,
    ),
    ep.ExtractionInfo(
        result_key="Energy_FEDU",
        name_or_column="HOPE_ENERGY_Ele",
        unit=u.eV,
    ),
    ep.ExtractionInfo(
        result_key="FEDU",
        name_or_column="FEDU",
        unit=(u.cm**2 * u.s * u.sr * u.keV) ** (-1),
    ),
]

# %% [markdown]
# In this example, we want to download the data from the server as this is how it is done for most data sets. The file_name_stem contains a pattern (YYYYMMDD) to describe the date of the file. While loading the data, this pattern will be replaced by the correct date. A similar pattern is used for the download url. The file_name_stem also contains the regex expression '.{6}', which is used to find files with different versions. The most up-to-date version will always be downloaded.

# %%
from datetime import datetime, timezone

start_time = datetime(2017, 7, 8, tzinfo=timezone.utc)
end_time = datetime(2017, 7, 9, 23, 59,59, tzinfo=timezone.utc)

file_name_stem = "rbspa_rel04_ect-hope-pa-l3_YYYYMMDD_.{6}.cdf"

ep.download(start_time, end_time,
             save_path=".",
             download_url="https://spdf.gsfc.nasa.gov/pub/data/rbsp/rbspa/l3/ect/hope/pitchangle/rel04/YYYY/",
             file_name_stem=file_name_stem,
             file_cadence="daily",
             method="request",
             skip_existing=True)

variables = ep.extract_variables_from_files(start_time, end_time, "daily",
                                             data_path=".", file_name_stem=file_name_stem,
                                             extraction_infos=extraction_infos)
variables
# Out:
# File already exists, skipping download: rbspa_rel04_ect-hope-pa-l3_20170708_v7.4.0.cdf
# File already exists, skipping download: rbspa_rel04_ect-hope-pa-l3_20170709_v7.4.0.cdf
# Extracting variables ...
# Concatenating data for Epoch_Ele ...
# Concatenating data for HOPE_ENERGY_Ele ...
# Concatenating data for FEDU ...
# {'Epoch': Variable holding (8346,) data points with metadata: VariableMetadata(unit=Unit("tt2000"), original_cadence_seconds=0, source_files=['rbspa_rel04_ect-hope-pa-l3_20170708_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170709_v7.4.0.cdf'], description='', processing_notes='', standard_name=''),
#  'Energy_FEDU': Variable holding (8346, 72) data points with metadata: VariableMetadata(unit=Unit("eV"), original_cadence_seconds=0, source_files=['rbspa_rel04_ect-hope-pa-l3_20170708_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170709_v7.4.0.cdf'], description='', processing_notes='', standard_name=''),
#  'FEDU': Variable holding (8346, 11, 72) data points with metadata: VariableMetadata(unit=Unit("1 / (keV s sr cm2)"), original_cadence_seconds=0, source_files=['rbspa_rel04_ect-hope-pa-l3_20170708_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170709_v7.4.0.cdf'], description='', processing_notes='', standard_name='')}
